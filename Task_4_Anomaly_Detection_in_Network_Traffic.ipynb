# %%
import pandas as pd

# %%
df=pd.read_csv('/content/network_traffic_data.csv')

# %%
df
# Out:
#        Duration Protocol       SourceIP  DestinationIP  SourcePort  \
# 0     24.077749      TCP  192.168.1.239  192.168.1.234        8055
# 1     97.252384     ICMP  192.168.1.176   192.168.1.82       63174
# 2     85.842654      TCP  192.168.1.120  192.168.1.113       30873
# 3     79.196991      UDP  192.168.1.212  192.168.1.140        4410
# 4     34.928018      TCP   192.168.1.17  192.168.1.223        4702
# ...         ...      ...            ...            ...         ...
# 1995  94.038562      UDP   192.168.1.16   192.168.1.82       41118
# 1996  59.318259      TCP   192.168.1.57   192.168.1.34       22287
# 1997  87.811070     ICMP  192.168.1.190  192.168.1.143       16543
# 1998  75.921165      UDP  192.168.1.107  192.168.1.183       34460
# 1999  31.948450     ICMP   192.168.1.90  192.168.1.104       36758
#
#       DestinationPort  PacketCount  ByteCount   Label
# 0                   1          827     198244  Attack
# ...

# %%
df.head()
# Out:
#     Duration Protocol       SourceIP  DestinationIP  SourcePort  \
# 0  24.077749      TCP  192.168.1.239  192.168.1.234        8055
# 1  97.252384     ICMP  192.168.1.176   192.168.1.82       63174
# 2  85.842654      TCP  192.168.1.120  192.168.1.113       30873
# 3  79.196991      UDP  192.168.1.212  192.168.1.140        4410
# 4  34.928018      TCP   192.168.1.17  192.168.1.223        4702
#
#    DestinationPort  PacketCount  ByteCount   Label
# 0                1          827     198244  Attack
# 1              687          673    1202973  Normal
# 2              570          319     984671  Attack
# 3              683          375      36284  Normal
# 4              989          465     817463  Normal

# %%
df.tail()
# Out:
#        Duration Protocol       SourceIP  DestinationIP  SourcePort  \
# 1995  94.038562      UDP   192.168.1.16   192.168.1.82       41118
# 1996  59.318259      TCP   192.168.1.57   192.168.1.34       22287
# 1997  87.811070     ICMP  192.168.1.190  192.168.1.143       16543
# 1998  75.921165      UDP  192.168.1.107  192.168.1.183       34460
# 1999  31.948450     ICMP   192.168.1.90  192.168.1.104       36758
#
#       DestinationPort  PacketCount  ByteCount   Label
# 1995              268          877     707010  Attack
# 1996               96          444    1473730  Attack
# 1997              210          132     218234  Normal
# 1998              426          991     134952  Normal
# 1999              155          197     593208  Normal

# %%
df.describe()
# Out:
#           Duration    SourcePort  DestinationPort  PacketCount     ByteCount
# count  2000.000000   2000.000000       2000.00000  2000.000000  2.000000e+03
# mean     50.294689  32897.035000        519.86550   490.051000  7.232092e+05
# std      28.837966  18477.821753        293.19047   290.012322  4.338501e+05
# min       0.014723   1098.000000          1.00000     1.000000  1.304000e+03
# 25%      24.476457  16770.750000        261.00000   230.000000  3.484270e+05
# 50%      50.818980  32930.500000        533.50000   489.000000  7.076935e+05
# 75%      75.059327  49061.250000        768.00000   741.250000  1.105676e+06
# max      99.995156  65461.000000       1022.00000   999.000000  1.499009e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         2000 non-null   float64
#  1   Protocol         2000 non-null   object
#  2   SourceIP         2000 non-null   object
#  3   DestinationIP    2000 non-null   object
#  4   SourcePort       2000 non-null   int64
#  5   DestinationPort  2000 non-null   int64
#  6   PacketCount      2000 non-null   int64
#  7   ByteCount        2000 non-null   int64
#  8   Label            2000 non-null   object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 140.8+ KB

# %%
df.isnull().sum()
# Out:
# Duration           0
# Protocol           0
# SourceIP           0
# DestinationIP      0
# SourcePort         0
# DestinationPort    0
# PacketCount        0
# ByteCount          0
# Label              0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(df['Duration'], bins=50)
plt.xlabel('Duration')
plt.ylabel('Frequency')
plt.title('Duration Distribution')
plt.show()

# %%
plt.hist(df['Protocol'], bins=50)
plt.xlabel('Protocol')
plt.ylabel('Frequency')
plt.title('Protocol Distribution')
plt.show()

# %%
SourceIP_counts = df['SourceIP'].value_counts()
plt.figure(figsize=(14, 7))
sns.barplot(x=SourceIP_counts.index, y=SourceIP_counts.values, palette='viridis')
plt.xlabel('Source IP')
plt.ylabel('Frequency')
plt.title('Source IP Distribution (Bar Plot)')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-35-79c29bb8b25f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=SourceIP_counts.index, y=SourceIP_counts.values, palette='viridis')

# %%
plt.hist(df['DestinationIP'], bins=50)
plt.xlabel('DestinationIP')
plt.ylabel('Frequency')
plt.title('DestinationIP Distribution')
plt.show()

# %%
plt.hist(df['PacketCount'], bins=50)
plt.xlabel('PacketCount')
plt.ylabel('Frequency')
plt.title('PacketCount Distribution')
plt.show()

# %%
plt.hist(df['ByteCount'], bins=50)
plt.xlabel('ByteCount')
plt.ylabel('Frequency')
plt.title('ByteCount Distribution')
plt.show()

# %%
features = ['Duration','SourcePort', 'DestinationPort', 'PacketCount', 'ByteCount']

# Heatmap of feature correlations
plt.figure(figsize=(12, 8))
sns.heatmap(df[features].corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoders = {}
for column in ['Protocol', 'SourceIP', 'DestinationIP']:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
df
# Out:
#        Duration  Protocol  SourceIP  DestinationIP  SourcePort  \
# 0     24.077749         1       155            150        8055
# 1     97.252384         0        85            236       63174
# 2     85.842654         1        24             16       30873
# 3     79.196991         2       126             46        4410
# 4     34.928018         1        78            138        4702
# ...         ...       ...       ...            ...         ...
# 1995  94.038562         2        67            236       41118
# 1996  59.318259         1       208            183       22287
# 1997  87.811070         0       101             49       16543
# 1998  75.921165         2         9             93       34460
# 1999  31.948450         0       245              6       36758
#
#       DestinationPort  PacketCount  ByteCount   Label
# 0                   1          827     198244  Attack
# 1                 687          673    1202973  Normal
# ...

# %%
features = ['Duration', 'Protocol', 'SourcePort', 'DestinationPort', 'PacketCount', 'ByteCount']
final_data = df[features]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(final_data)

# %%
df
# Out:
#        Duration  Protocol  SourceIP  DestinationIP  SourcePort  \
# 0     24.077749         1       155            150        8055
# 1     97.252384         0        85            236       63174
# 2     85.842654         1        24             16       30873
# 3     79.196991         2       126             46        4410
# 4     34.928018         1        78            138        4702
# ...         ...       ...       ...            ...         ...
# 1995  94.038562         2        67            236       41118
# 1996  59.318259         1       208            183       22287
# 1997  87.811070         0       101             49       16543
# 1998  75.921165         2         9             93       34460
# 1999  31.948450         0       245              6       36758
#
#       DestinationPort  PacketCount  ByteCount   Label
# 0                   1          827     198244  Attack
# 1                 687          673    1202973  Normal
# ...

# %%
from sklearn.ensemble import IsolationForest
model = IsolationForest(n_estimators=100, contamination=0.01, random_state=42)
model.fit(scaled_data)
df['anomaly'] = model.predict(scaled_data)
df['anomaly'] = df['anomaly'].map({1: 0, -1: 1})

# %%
anomalies = df[df['anomaly'] == 1]
normal = df[df['anomaly'] == 0]
# Visualize anomalies in a scatter plot of two selected features (e.g., Duration vs PacketCount)
plt.figure(figsize=(10, 6))
plt.scatter(normal['Duration'], normal['PacketCount'], c='blue', label='Normal')
plt.scatter(anomalies['Duration'], anomalies['PacketCount'], c='red', label='Anomaly')
plt.xlabel('Duration')
plt.ylabel('Packet Count')
plt.legend()
plt.title('Anomalies in Network Traffic')
plt.show()

# %%
df['PacketSizePerDuration'] = df['ByteSizePerPacket'] / (df['PacketSizePerDuration']+ 1e-9)
df['ByteSizePerPacket'] = df['ByteSizePerPacket'] / (df['PacketSizePerDuration']+ 1e-9)

anomalies = df[df['anomaly'] == 1]
normal = df[df['anomaly'] == 0]
plt.figure(figsize=(10, 6))
plt.scatter(normal['PacketSizePerDuration'], normal['ByteSizePerPacket'], c='green', label='Normal')
plt.scatter(anomalies['PacketSizePerDuration'], anomalies['ByteSizePerPacket'], c='yellow', label='Anomaly')
plt.xlabel('PacketSizePerDuration')
plt.ylabel('ByteSizePerPacket')
plt.legend()
plt.title('Anomalies in Network Traffic')
plt.show()
